# %%
import sys, pickle,networkx as nx,matplotlib.pyplot as plt

# %%
graph1=open('../data/graphs_2006_2016.pkl','rb')
grp=pickle.load(graph1)

# %%
y2014k=[k for k in grp.keys() if '2014' in k]
gInfo=[grp[k]['cgraph'][0] for k in y2014k]
gInfoFlat=[item for sublist in gInfo for item in sublist]
gInfoTrim=[m for m in gInfoFlat if m[2] >4]

# %%
G=nx.DiGraph()
G.add_weighted_edges_from(gInfoTrim)
G0=G.to_undirected()

# %%
nx.draw(G)
plt.draw()
plt.show()
# Out:
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/collections.py:548: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == 'face':

# %%
nx.draw_networkx_labels(G,pos=nx.spring_layout(G))
plt.draw()
plt.show()

# %%
# ?nx.spring_layout

# %%
gInfoTrim
# Out:
# [('kenya', 'china', 15),
#  ('kenya', 'ethiopia', 12),
#  ('kenya', 'ghana', 6),
#  ('kenya', 'kenya', 204),
#  ('kenya', 'mali', 5),
#  ('kenya', 'niger', 10),
#  ('kenya', 'nigeria', 10),
#  ('kenya', 'rwanda', 7),
#  ('kenya', 'south africa', 9),
#  ('kenya', 'tanzania', 5),
#  ('kenya', 'uganda', 47),
#  ('china', 'australia', 28),
#  ('china', 'china', 264),
#  ('china', 'germany', 7),
#  ('china', 'india', 11),
#  ('china', 'indonesia', 11),
#  ('china', 'japan', 58),
#  ('china', 'kenya', 6),
#  ('china', 'north korea', 11),
#  ('china', 'south korea', 5),
#  ('china', 'malaysia', 29),
#  ('china', 'mexico', 20),
#  ('algeria', 'algeria', 134),
#  ('algeria', 'argentina', 22),
#  ('algeria', 'australia', 12),
#  ('algeria', 'austria', 29),
#  ('algeria', 'belgium', 8),
#  ('algeria', 'brazil', 19),
#  ('algeria', 'cameroon', 34),
#  ('algeria', 'china', 6),
#  ('algeria', 'egypt', 11),
#  ('algeria', 'france', 70),
#  ('algeria', 'germany', 30),
#  ('algeria', 'india', 11),
# ...
